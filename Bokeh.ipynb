# %% [markdown]
# <a href="https://colab.research.google.com/github/anushi12/Python-Libraries/blob/main/Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
# !pip install bokeh

# %%
# !pip install bokeh_sampledata

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p = figure(title = 'test flowers')
p.xaxis.axis_label = 'petal length'
p.yaxis.axis_label = ' sepal_width'

p.circle(flowers['petal_length'], flowers['sepal_width'])
show(p)
# Out:
#   <div id="a92cfb47-ce3b-4b3f-a3a8-f33b98a8f0f7" data-root-id="p1364" style="display: contents;"></div>

# %%
print(flowers.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = [1, 2, 3,3 , 5,4 ]
y = [6, 5, 7, 8, 9,10]

output_file('line.html')

p = figure(title = 'line graph')
p.xaxis.axis_label = 'x axis'
p.yaxis.axis_label = 'y axis'

p.line(x, y)
show(p)
# Out:
#   <div id="f3ed915c-7141-4a84-880f-c9b40fb2dad3" data-root-id="p1276" style="display: contents;"></div>

# %%
x = [1, 2, 3,3 , 5,4 ]
y = [6, 5, 7, 8, 9,10]

output_file('line.html')

p = figure(title = 'line graph')
p.xaxis.axis_label = 'x axis'
p.yaxis.axis_label = 'y axis'

p.scatter(x, y, fill_color ='green', legend_label = 'green points', size = 20)
show(p)
# Out:
#   <div id="aa386048-c0db-44b2-b93d-19b447d4a795" data-root-id="p1720" style="display: contents;"></div>
